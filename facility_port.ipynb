# %% [markdown]
# # Create a FABRIC Facility Port
#
# This notebook shows how to use create an facility port to connect your FABRIC experiment to an external facility.

# %% [markdown]
# ## Import the FABlib Library

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager

fablib = fablib_manager()
                     
fablib.show_config();
# Out:
# <style type="text/css">
# #T_63123 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_63123 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_63123 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_63123_row0_col0, #T_63123_row0_col1, #T_63123_row1_col0, #T_63123_row1_col1, #T_63123_row2_col0, #T_63123_row2_col1, #T_63123_row3_col0, #T_63123_row3_col1, #T_63123_row4_col0, #T_63123_row4_col1, #T_63123_row5_col0, #T_63123_row5_col1, #T_63123_row6_col0, #T_63123_row6_col1, #T_63123_row7_col0, #T_63123_row7_col1, #T_63123_row8_col0, #T_63123_row8_col1, #T_63123_row9_col0, #T_63123_row9_col1, #T_63123_row10_col0, #T_63123_row10_col1, #T_63123_row11_col0, #T_63123_row11_col1, #T_63123_row12_col0, #T_63123_row12_col1, #T_63123_row13_col0, #T_63123_row13_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_63123">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_63123_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_63123_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_63123_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_63123_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_63123_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_63123_row2_col1" class="data row2 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_63123_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_63123_row3_col1" class="data row3 col1" >f1f5b0f8-0eef-40f3-940e-c4c8ff2d60ca</td>
#     </tr>
#     <tr>
#       <td id="T_63123_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_63123_row4_col1" class="data row4 col1" >marcos_schwarz_0034669026</td>
#     </tr>
#     <tr>
#       <td id="T_63123_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_63123_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_63123_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_63123_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_63123_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_63123_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_63123_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_63123_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_63123_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_63123_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_63123_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_63123_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_63123_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_63123_row11_col1" class="data row11 col1" >/home/fabric/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_63123_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_63123_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_63123_row13_col0" class="data row13 col0" >Version</td>
#       <td id="T_63123_row13_col1" class="data row13 col1" >1.5.5</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Create the Experiment Slice
#
# The following creates a single node with basic compute capabilities. You build a slice by creating a new slice and adding resources to the slice. After you build the slice, you must submit a request for the slice to be instantiated.
#
# By default, the submit function will block until the node is ready and will display the progress of your slice being built.

# %%
slice_name = "MySlice"

facility_port='AmLight-EXP-Layer2-FIU'
facility_port_site='FIU'
facility_port_vlan='4000'

#Create a slice
slice = fablib.new_slice(name=slice_name)

node = slice.add_node(name=f"Node1", site=facility_port_site)

node.add_post_boot_upload_directory('node_tools','.')
node.add_post_boot_execute('node_tools/enable_docker.sh {{ _self_.image }}')
node.add_post_boot_execute('sudo node_tools/install.sh')

#node_iface = node.add_component(model='NIC_ConnectX_6', name="nic1").get_interfaces()[0]
node_iface = node.add_component(model='NIC_Basic', name="nic1").get_interfaces()[0]

facility_port = slice.add_facility_port(name=facility_port, site=facility_port_site, vlan=facility_port_vlan)
facility_port_interface =facility_port.get_interfaces()[0]

print(f"facility_port.get_site(): {facility_port.get_site()}")

#net = slice.add_l2network(name=f'net_facility_port', interfaces=[node_iface,facility_port_interface])
net = slice.add_l2network(name=f'net_facility_port', interfaces=[])
net.add_interface(node_iface)
net.add_interface(facility_port_interface)

#Submit the Request
slice.submit();
# Out:
# Retry: 11, Time: 317 sec
# <style type="text/css">
# #T_397d7 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_397d7 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_397d7 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_397d7_row0_col0, #T_397d7_row0_col1, #T_397d7_row1_col0, #T_397d7_row1_col1, #T_397d7_row2_col0, #T_397d7_row2_col1, #T_397d7_row3_col0, #T_397d7_row3_col1, #T_397d7_row4_col0, #T_397d7_row4_col1, #T_397d7_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_397d7_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_397d7">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_397d7_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_397d7_row0_col1" class="data row0 col1" >814285c6-1a3b-4ad2-956a-aa002515bda7</td>
#     </tr>
#     <tr>
#       <td id="T_397d7_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_397d7_row1_col1" class="data row1 col1" >MySlice</td>
#     </tr>
#     <tr>
#       <td id="T_397d7_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_397d7_row2_col1" class="data row2 col1" >2023-11-14 23:46:21 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_397d7_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_397d7_row3_col1" class="data row3 col1" >2023-11-13 23:46:21 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_397d7_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_397d7_row4_col1" class="data row4 col1" >f1f5b0f8-0eef-40f3-940e-c4c8ff2d60ca</td>
#     </tr>
#     <tr>
#       <td id="T_397d7_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_397d7_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_63fd1 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_63fd1 th {
#   text-align: left;
# }
# #T_63fd1 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_63fd1 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_63fd1 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_63fd1_row0_col0, #T_63fd1_row0_col1, #T_63fd1_row0_col2, #T_63fd1_row0_col3, #T_63fd1_row0_col4, #T_63fd1_row0_col5, #T_63fd1_row0_col6, #T_63fd1_row0_col7, #T_63fd1_row0_col8, #T_63fd1_row0_col9, #T_63fd1_row0_col10, #T_63fd1_row0_col13, #T_63fd1_row0_col14, #T_63fd1_row0_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_63fd1_row0_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_63fd1_row0_col12 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_63fd1">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_63fd1_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_63fd1_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_63fd1_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_63fd1_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_63fd1_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_63fd1_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_63fd1_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_63fd1_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_63fd1_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_63fd1_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_63fd1_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_63fd1_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_63fd1_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_63fd1_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_63fd1_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_63fd1_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_63fd1_row0_col0" class="data row0 col0" >9ab3a506-4842-4940-8337-6683a501fefa</td>
#       <td id="T_63fd1_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_63fd1_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_63fd1_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_63fd1_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_63fd1_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_63fd1_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_63fd1_row0_col7" class="data row0 col7" >fiu-w2.fabric-testbed.net</td>
#       <td id="T_63fd1_row0_col8" class="data row0 col8" >FIU</td>
#       <td id="T_63fd1_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_63fd1_row0_col10" class="data row0 col10" >131.94.57.43</td>
#       <td id="T_63fd1_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_63fd1_row0_col12" class="data row0 col12" ></td>
#       <td id="T_63fd1_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@131.94.57.43</td>
#       <td id="T_63fd1_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_63fd1_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_549e8 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_549e8 th {
#   text-align: left;
# }
# #T_549e8 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_549e8 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_549e8 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_549e8_row0_col0, #T_549e8_row0_col1, #T_549e8_row0_col2, #T_549e8_row0_col3, #T_549e8_row0_col4, #T_549e8_row0_col5, #T_549e8_row0_col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_549e8_row0_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_549e8_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_549e8">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_549e8_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_549e8_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_549e8_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_549e8_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_549e8_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_549e8_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_549e8_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_549e8_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_549e8_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_549e8_row0_col0" class="data row0 col0" >94e9f642-e850-4e57-9d50-4e616d6b7778</td>
#       <td id="T_549e8_row0_col1" class="data row0 col1" >net_facility_port</td>
#       <td id="T_549e8_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_549e8_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_549e8_row0_col4" class="data row0 col4" >FIU</td>
#       <td id="T_549e8_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_549e8_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_549e8_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_549e8_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b4d3a caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_b4d3a th {
#   text-align: left;
# }
# #T_b4d3a tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b4d3a tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b4d3a .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b4d3a_row0_col0, #T_b4d3a_row0_col1, #T_b4d3a_row0_col2, #T_b4d3a_row0_col3, #T_b4d3a_row0_col4, #T_b4d3a_row0_col5, #T_b4d3a_row0_col6, #T_b4d3a_row0_col7, #T_b4d3a_row0_col8, #T_b4d3a_row0_col9, #T_b4d3a_row0_col10, #T_b4d3a_row0_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_b4d3a">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_b4d3a_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_b4d3a_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_b4d3a_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_b4d3a_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_b4d3a_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_b4d3a_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_b4d3a_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_b4d3a_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_b4d3a_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_b4d3a_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_b4d3a_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_b4d3a_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b4d3a_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_b4d3a_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_b4d3a_row0_col2" class="data row0 col2" >Node1</td>
#       <td id="T_b4d3a_row0_col3" class="data row0 col3" >net_facility_port</td>
#       <td id="T_b4d3a_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_b4d3a_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_b4d3a_row0_col6" class="data row0 col6" ></td>
#       <td id="T_b4d3a_row0_col7" class="data row0 col7" >02:59:B4:EA:50:7E</td>
#       <td id="T_b4d3a_row0_col8" class="data row0 col8" >eth1</td>
#       <td id="T_b4d3a_row0_col9" class="data row0 col9" >eth1</td>
#       <td id="T_b4d3a_row0_col10" class="data row0 col10" >fe80::45e5:fb49:b4a7:b9ae</td>
#       <td id="T_b4d3a_row0_col11" class="data row0 col11" >6</td>
#     </tr>
#   </tbody>
# </table>
# Time to print interfaces 318 seconds

# %% [markdown]
# ## Observe the Slice's Attributes

# %%
slice.show()
slice.list_nodes()
slice.list_networks()
slice.list_interfaces()
# Out:
# <style type="text/css">
# #T_12bbf tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_12bbf tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_12bbf caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_12bbf_row0_col0, #T_12bbf_row0_col1, #T_12bbf_row1_col0, #T_12bbf_row1_col1, #T_12bbf_row2_col0, #T_12bbf_row2_col1, #T_12bbf_row3_col0, #T_12bbf_row3_col1, #T_12bbf_row4_col0, #T_12bbf_row4_col1, #T_12bbf_row5_col0, #T_12bbf_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_12bbf">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_12bbf_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_12bbf_row0_col1" class="data row0 col1" >814285c6-1a3b-4ad2-956a-aa002515bda7</td>
#     </tr>
#     <tr>
#       <td id="T_12bbf_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_12bbf_row1_col1" class="data row1 col1" >MySlice</td>
#     </tr>
#     <tr>
#       <td id="T_12bbf_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_12bbf_row2_col1" class="data row2 col1" >2023-11-14 23:46:21 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_12bbf_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_12bbf_row3_col1" class="data row3 col1" >2023-11-13 23:46:21 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_12bbf_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_12bbf_row4_col1" class="data row4 col1" >f1f5b0f8-0eef-40f3-940e-c4c8ff2d60ca</td>
#     </tr>
#     <tr>
#       <td id="T_12bbf_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_12bbf_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_f0fcd caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_f0fcd th {
#   text-align: left;
# }
# #T_f0fcd tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_f0fcd tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_f0fcd .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_f0fcd_row0_col0, #T_f0fcd_row0_col1, #T_f0fcd_row0_col2, #T_f0fcd_row0_col3, #T_f0fcd_row0_col4, #T_f0fcd_row0_col5, #T_f0fcd_row0_col6, #T_f0fcd_row0_col7, #T_f0fcd_row0_col8, #T_f0fcd_row0_col9, #T_f0fcd_row0_col10, #T_f0fcd_row0_col11, #T_f0fcd_row0_col12, #T_f0fcd_row0_col13, #T_f0fcd_row0_col14, #T_f0fcd_row0_col15 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_f0fcd">
#   <caption>Nodes</caption>
#   <thead>
#     <tr>
#       <th id="T_f0fcd_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_f0fcd_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_f0fcd_level0_col2" class="col_heading level0 col2" >Cores</th>
#       <th id="T_f0fcd_level0_col3" class="col_heading level0 col3" >RAM</th>
#       <th id="T_f0fcd_level0_col4" class="col_heading level0 col4" >Disk</th>
#       <th id="T_f0fcd_level0_col5" class="col_heading level0 col5" >Image</th>
#       <th id="T_f0fcd_level0_col6" class="col_heading level0 col6" >Image Type</th>
#       <th id="T_f0fcd_level0_col7" class="col_heading level0 col7" >Host</th>
#       <th id="T_f0fcd_level0_col8" class="col_heading level0 col8" >Site</th>
#       <th id="T_f0fcd_level0_col9" class="col_heading level0 col9" >Username</th>
#       <th id="T_f0fcd_level0_col10" class="col_heading level0 col10" >Management IP</th>
#       <th id="T_f0fcd_level0_col11" class="col_heading level0 col11" >State</th>
#       <th id="T_f0fcd_level0_col12" class="col_heading level0 col12" >Error</th>
#       <th id="T_f0fcd_level0_col13" class="col_heading level0 col13" >SSH Command</th>
#       <th id="T_f0fcd_level0_col14" class="col_heading level0 col14" >Public SSH Key File</th>
#       <th id="T_f0fcd_level0_col15" class="col_heading level0 col15" >Private SSH Key File</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_f0fcd_row0_col0" class="data row0 col0" >9ab3a506-4842-4940-8337-6683a501fefa</td>
#       <td id="T_f0fcd_row0_col1" class="data row0 col1" >Node1</td>
#       <td id="T_f0fcd_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_f0fcd_row0_col3" class="data row0 col3" >8</td>
#       <td id="T_f0fcd_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_f0fcd_row0_col5" class="data row0 col5" >default_rocky_8</td>
#       <td id="T_f0fcd_row0_col6" class="data row0 col6" >qcow2</td>
#       <td id="T_f0fcd_row0_col7" class="data row0 col7" >fiu-w2.fabric-testbed.net</td>
#       <td id="T_f0fcd_row0_col8" class="data row0 col8" >FIU</td>
#       <td id="T_f0fcd_row0_col9" class="data row0 col9" >rocky</td>
#       <td id="T_f0fcd_row0_col10" class="data row0 col10" >131.94.57.43</td>
#       <td id="T_f0fcd_row0_col11" class="data row0 col11" >Active</td>
#       <td id="T_f0fcd_row0_col12" class="data row0 col12" ></td>
#       <td id="T_f0fcd_row0_col13" class="data row0 col13" >ssh -i /home/fabric/work/fabric_config/slice_key -F /home/fabric/work/fabric_config/ssh_config rocky@131.94.57.43</td>
#       <td id="T_f0fcd_row0_col14" class="data row0 col14" >/home/fabric/work/fabric_config/slice_key.pub</td>
#       <td id="T_f0fcd_row0_col15" class="data row0 col15" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_b513f caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_b513f th {
#   text-align: left;
# }
# #T_b513f tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b513f tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_b513f .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_b513f_row0_col0, #T_b513f_row0_col1, #T_b513f_row0_col2, #T_b513f_row0_col3, #T_b513f_row0_col4, #T_b513f_row0_col5, #T_b513f_row0_col6, #T_b513f_row0_col7, #T_b513f_row0_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_b513f">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_b513f_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_b513f_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_b513f_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_b513f_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_b513f_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_b513f_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_b513f_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_b513f_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_b513f_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_b513f_row0_col0" class="data row0 col0" >94e9f642-e850-4e57-9d50-4e616d6b7778</td>
#       <td id="T_b513f_row0_col1" class="data row0 col1" >net_facility_port</td>
#       <td id="T_b513f_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_b513f_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_b513f_row0_col4" class="data row0 col4" >FIU</td>
#       <td id="T_b513f_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_b513f_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_b513f_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_b513f_row0_col8" class="data row0 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7eb76 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_7eb76 th {
#   text-align: left;
# }
# #T_7eb76 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7eb76 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_7eb76 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7eb76_row0_col0, #T_7eb76_row0_col1, #T_7eb76_row0_col2, #T_7eb76_row0_col3, #T_7eb76_row0_col4, #T_7eb76_row0_col5, #T_7eb76_row0_col6, #T_7eb76_row0_col7, #T_7eb76_row0_col8, #T_7eb76_row0_col9, #T_7eb76_row0_col10, #T_7eb76_row0_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_7eb76">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_7eb76_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_7eb76_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_7eb76_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_7eb76_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_7eb76_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_7eb76_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_7eb76_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_7eb76_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_7eb76_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_7eb76_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_7eb76_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_7eb76_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7eb76_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_7eb76_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_7eb76_row0_col2" class="data row0 col2" >Node1</td>
#       <td id="T_7eb76_row0_col3" class="data row0 col3" >net_facility_port</td>
#       <td id="T_7eb76_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_7eb76_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_7eb76_row0_col6" class="data row0 col6" ></td>
#       <td id="T_7eb76_row0_col7" class="data row0 col7" >02:59:B4:EA:50:7E</td>
#       <td id="T_7eb76_row0_col8" class="data row0 col8" >eth1</td>
#       <td id="T_7eb76_row0_col9" class="data row0 col9" >eth1</td>
#       <td id="T_7eb76_row0_col10" class="data row0 col10" >10.40.0.101</td>
#       <td id="T_7eb76_row0_col11" class="data row0 col11" >6</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_7eb76 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_7eb76 th {
#   text-align: left;
# }
# #T_7eb76 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7eb76 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_7eb76 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_7eb76_row0_col0, #T_7eb76_row0_col1, #T_7eb76_row0_col2, #T_7eb76_row0_col3, #T_7eb76_row0_col4, #T_7eb76_row0_col5, #T_7eb76_row0_col6, #T_7eb76_row0_col7, #T_7eb76_row0_col8, #T_7eb76_row0_col9, #T_7eb76_row0_col10, #T_7eb76_row0_col11 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_7eb76">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_7eb76_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_7eb76_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_7eb76_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_7eb76_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_7eb76_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_7eb76_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_7eb76_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_7eb76_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_7eb76_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_7eb76_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_7eb76_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_7eb76_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_7eb76_row0_col0" class="data row0 col0" >Node1-nic1-p1</td>
#       <td id="T_7eb76_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_7eb76_row0_col2" class="data row0 col2" >Node1</td>
#       <td id="T_7eb76_row0_col3" class="data row0 col3" >net_facility_port</td>
#       <td id="T_7eb76_row0_col4" class="data row0 col4" >100</td>
#       <td id="T_7eb76_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_7eb76_row0_col6" class="data row0 col6" ></td>
#       <td id="T_7eb76_row0_col7" class="data row0 col7" >02:59:B4:EA:50:7E</td>
#       <td id="T_7eb76_row0_col8" class="data row0 col8" >eth1</td>
#       <td id="T_7eb76_row0_col9" class="data row0 col9" >eth1</td>
#       <td id="T_7eb76_row0_col10" class="data row0 col10" >10.40.0.101</td>
#       <td id="T_7eb76_row0_col11" class="data row0 col11" >6</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Run the Experiment
#
# Most experiments will require automated configuration and execution. You can use the fablib library to execute arbitrary commands on your node.
#
# The following code demonstrates how to use fablib to execute a "Hello, FABRIC" bash script. The library uses the bastion and VM keys defined at the top of this notebook to jump through the bastion host and execute the script.

# %%
from ipaddress import ip_address, IPv4Address, IPv6Address, IPv4Network, IPv6Network

subnet = IPv4Network("10.40.0.0/24")
available_ips = list(subnet)[2:]

# %%
node1 = slice.get_node(name=f"Node1")        
node1_iface = node1.get_interface(network_name=f'net_facility_port') 
node1_addr = available_ips.pop(99)
print(f"node1_addr: {node1_addr}")
node1_iface.ip_addr_add(addr=node1_addr, subnet=subnet)

stdout, stderr = node1.execute(f'ip addr show {node1_iface.get_os_interface()}')

stdout, stderr = node1.execute(f'sudo ip link set dev {node1_iface.get_physical_os_interface_name()} up')

stdout, stderr = node1.execute(f'sudo ip link set dev {node1_iface.get_os_interface()} up')
# Out:
# node1_addr: 10.40.0.101
# 3: eth1: <BROADCAST,MULTICAST,UP,LOWER_UP> mtu 1500 qdisc mq state UP group default qlen 1000
#     link/ether 02:59:b4:ea:50:7e brd ff:ff:ff:ff:ff:ff
#     inet 10.40.0.101/24 scope global eth1
#        valid_lft forever preferred_lft forever
#     inet6 fe80::45e5:fb49:b4a7:b9ae/64 scope link noprefixroute
#        valid_lft forever preferred_lft forever

# %%
node1 = slice.get_node(name=f"Node1")     
node1_iface = node1.get_interface(network_name=f'net_facility_port') 

stdout, stderr = node1.execute(f'ping -c 5 10.40.0.10')

# %% [markdown]
# ## Configure Slice Parameters

# %%
slice_name='MySlice'

# %% [markdown]
# ## Get and Renew the Slice
#
# You slice is in the list of all your slices. You can loop through the list of slices to get the slice. Python has a standard tool to filter lists. Try using a lambda function to filter out your slice using its name.
#
# The new end date is in UTC.

# %%
from datetime import datetime
from datetime import timezone
from datetime import timedelta

#Set end host to now plus 1 day
end_date = (datetime.now(timezone.utc) + timedelta(days=6)).strftime("%Y-%m-%d %H:%M:%S %z")

try:
    slice = fablib.get_slice(name=slice_name)

    slice.renew(end_date)
except Exception as e:
    print(f"Exception: {e}")

# %%
slice.show()
# Out:
# <style type="text/css">
# #T_954b5 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_954b5 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_954b5 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_954b5_row0_col0, #T_954b5_row0_col1, #T_954b5_row1_col0, #T_954b5_row1_col1, #T_954b5_row2_col0, #T_954b5_row2_col1, #T_954b5_row3_col0, #T_954b5_row3_col1, #T_954b5_row4_col0, #T_954b5_row4_col1, #T_954b5_row5_col0, #T_954b5_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_954b5">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_954b5_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_954b5_row0_col1" class="data row0 col1" >814285c6-1a3b-4ad2-956a-aa002515bda7</td>
#     </tr>
#     <tr>
#       <td id="T_954b5_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_954b5_row1_col1" class="data row1 col1" >MySlice</td>
#     </tr>
#     <tr>
#       <td id="T_954b5_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_954b5_row2_col1" class="data row2 col1" >2023-11-20 21:54:11 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_954b5_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_954b5_row3_col1" class="data row3 col1" >2023-11-13 23:46:21 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_954b5_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_954b5_row4_col1" class="data row4 col1" >f1f5b0f8-0eef-40f3-940e-c4c8ff2d60ca</td>
#     </tr>
#     <tr>
#       <td id="T_954b5_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_954b5_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_954b5 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_954b5 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_954b5 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_954b5_row0_col0, #T_954b5_row0_col1, #T_954b5_row1_col0, #T_954b5_row1_col1, #T_954b5_row2_col0, #T_954b5_row2_col1, #T_954b5_row3_col0, #T_954b5_row3_col1, #T_954b5_row4_col0, #T_954b5_row4_col1, #T_954b5_row5_col0, #T_954b5_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_954b5">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_954b5_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_954b5_row0_col1" class="data row0 col1" >814285c6-1a3b-4ad2-956a-aa002515bda7</td>
#     </tr>
#     <tr>
#       <td id="T_954b5_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_954b5_row1_col1" class="data row1 col1" >MySlice</td>
#     </tr>
#     <tr>
#       <td id="T_954b5_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_954b5_row2_col1" class="data row2 col1" >2023-11-20 21:54:11 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_954b5_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_954b5_row3_col1" class="data row3 col1" >2023-11-13 23:46:21 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_954b5_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_954b5_row4_col1" class="data row4 col1" >f1f5b0f8-0eef-40f3-940e-c4c8ff2d60ca</td>
#     </tr>
#     <tr>
#       <td id="T_954b5_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_954b5_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Delete the Slice
#
# Please delete your slice when you are done with your experiment.

# %%
slice.delete()
